# %%
import pandas as pd
from pathlib import Path

# %%
# Name of the CSV file
file = Path("Resources/Homelessness_2014_2023.csv")

# %%
df = pd.read_csv(file)

# %%
df.head()
# Out:
#      Year State Overall Homeless Overall Homeless - Under 18  \
# 0  2014.0    AK            1,784                         397
# 1  2014.0    AL            4,561                         772
# 2  2014.0    AR            2,936                         355
# 3  2014.0    AS
# 4  2014.0    AZ           10,495                       2,679
#
#   Overall Homeless - Age 18 to 24 Overall Homeless - Over 24  \
# 0                             202                      1,185
# 1                             366                      3,423
# 2                             315                      2,266
# 3
# 4                           1,024                      6,792
#
#   Overall Homeless - Female Overall Homeless - Male  \
# 0                       799                     984
# 1                     1,681                   2,806
# 2                     1,113                   1,098
# 3
# 4                     3,900                   5,531
#
#   Overall Homeless - Transgender  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 570 entries, 0 to 569
# Data columns (total 31 columns):
#  #   Column                                                                     Non-Null Count  Dtype
# ---  ------                                                                     --------------  -----
#  0   Year                                                                       560 non-null    float64
#  1   State                                                                      570 non-null    object
#  2   Overall Homeless                                                           570 non-null    object
#  3   Overall Homeless - Under 18                                                570 non-null    object
#  4   Overall Homeless - Age 18 to 24                                            570 non-null    object
#  5   Overall Homeless - Over 24                                                 568 non-null    object
# ...

# %%
new_df = df.dropna()
new_df.tail()
# Out:
#        Year State Overall Homeless Overall Homeless - Under 18  \
# 564  2023.0    VT            3,295                         654
# 565  2023.0    WA           28,036                       4,386
# 566  2023.0    WI            4,861                       1,189
# 567  2023.0    WV            1,416                         125
# 568  2023.0    WY              532                          37
#
#     Overall Homeless - Age 18 to 24 Overall Homeless - Over 24  \
# 564                             247                      2,394
# 565                           1,897                     15,275
# 566                             279                      3,393
# 567                             136                      1,155
# 568                              62                        433
#
#     Overall Homeless - Female Overall Homeless - Male  \
# 564                     1,454                   1,810
# 565                    10,124                  17,283
# ...

# %%
# Calculate the number of unique authors in the DataFrame
state_count = len(new_df["State"].unique())
state_count
# Out:
# 56

# %%
new_df.to_csv('Resources/2014_2023_Data_Combo_cleaned.csv', index=False)

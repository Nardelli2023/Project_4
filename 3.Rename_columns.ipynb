# %%
import pandas as pd
from pathlib import Path

# %%
# Name of the CSV file
file = Path("Resources/2014_2023_Data_Combo_cleaned.csv")

# %%
df = pd.read_csv(file)

# %%
df.head()
# Out:
#    Year State Overall Homeless Overall Homeless - Under 18  \
# 0  2014    AK            1,784                         397
# 1  2014    AL            4,561                         772
# 2  2014    AR            2,936                         355
# 3  2014    AS
# 4  2014    AZ           10,495                       2,679
#
#   Overall Homeless - Age 18 to 24 Overall Homeless - Over 24  \
# 0                             202                      1,185
# 1                             366                      3,423
# 2                             315                      2,266
# 3
# 4                           1,024                      6,792
#
#   Overall Homeless - Female Overall Homeless - Male  \
# 0                       799                     984
# 1                     1,681                   2,806
# 2                     1,113                   1,098
# 3
# 4                     3,900                   5,531
#
#   Overall Homeless - Transgender  \
# ...

# %%
renamed_df = df.rename(columns={
    "Overall Homeless - Under 18":"Under 18",
    "Overall Homeless - Age 18 to 24":"Age 18 to 24",
    "Overall Homeless - Over 24":"Over 24",
    "Overall Homeless - Female":"Female",
    "Overall Homeless - Male":"Male",
    "Overall Homeless - Transgender":"Transgender",
    "Overall Homeless - Gender that is not Singularly Female or Male":"Non-binary",
    "Overall Homeless - Non-Hispanic/Non-Latin(o)(a)(x)":"Non-Hispanic/Non-Latin",
    "Overall Homeless - Hispanic/Latin(o)(a)(x)":"Hispanic/Latin",
    "Overall Homeless - White":"White",
    "Overall Homeless - Black, African American, or African":"African American",
    "Overall Homeless - Asian or Asian American":"Asian American",
    "Overall Homeless - American Indian, Alaska Native, or Indigenous":"Indigenous",
    "Overall Homeless - Native Hawaiian or Other Pacific Islander":"Pacific Islander",
    "Overall Homeless - Multiple Races":"Multiple Races",
    "Overall Homeless Veterans - Female":"Veterans - Female",
    "Overall Homeless Veterans - Male":"Veterans - Male",
    "Overall Homeless Veterans - Transgender":"Veterans - Transgender",
    "Overall Homeless Veterans - Gender that is not Singularly Female or Male":"Veterans-Non-binary",
    "Overall Homeless Veterans - Non-Hispanic/Non-Latin(o)(a)(x)":"Veterans - Non-Hispanic/Non-Latin",
    "Overall Homeless Veterans - Hispanic/Latin(o)(a)(x)":"Veterans - Hispanic/Latin",
    "Overall Homeless Veterans - White":"Veterans - White",
    "Overall Homeless Veterans - Black, African American, or African":"Veterans - African American",
    "Overall Homeless Veterans - Asian or Asian American":"Veterans - Asian American",
    "Overall Homeless Veterans - American Indian, Alaska Native, or Indigenous":"Veterans - Indigenous",
    "Overall Homeless Veterans - Native Hawaiian or Other Pacific Islander":"Veterans - Pacific Islander",
    "Overall Homeless Veterans - Multiple Races":"Veterans - Multiple Races"})
renamed_df.head()
# Out:
#    Year State Overall Homeless Under 18 Age 18 to 24 Over 24 Female   Male  \
# 0  2014    AK            1,784      397          202   1,185    799    984
# 1  2014    AL            4,561      772          366   3,423  1,681  2,806
# 2  2014    AR            2,936      355          315   2,266  1,113  1,098
# 3  2014    AS
# 4  2014    AZ           10,495    2,679        1,024   6,792  3,900  5,531
#
#   Transgender Non-binary  ... Veterans - Transgender Veterans-Non-binary  \
# 0           1        NaN  ...                      0                 NaN
# 1           4        NaN  ...                      1                 NaN
# 2           0        NaN  ...                      0                 NaN
# 3                    NaN  ...                                        NaN
# 4          15        NaN  ...                      3                 NaN
#
#   Veterans - Non-Hispanic/Non-Latin Veterans - Hispanic/Latin  \
# 0                               173                         5
# ...

# %%
renamed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 560 entries, 0 to 559
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Year                               560 non-null    int64
#  1   State                              560 non-null    object
#  2   Overall Homeless                   560 non-null    object
#  3   Under 18                           560 non-null    object
#  4   Age 18 to 24                       560 non-null    object
#  5   Over 24                            558 non-null    object
#  6   Female                             560 non-null    object
#  7   Male                               560 non-null    object
#  8   Transgender                        560 non-null    object
#  9   Non-binary                         443 non-null    object
#  10  Non-Hispanic/Non-Latin             560 non-null    object
# ...

# %%
renamed_df.to_csv('Resources/2014_2023_Data_Combo_cleaned_Renamed.csv', index=False)
